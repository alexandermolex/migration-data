# %%
import tkinter as tk
from tkinter import filedialog
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import altair as alt 
import os
import pathlib
from pathlib import Path
import time as tm

# %%
inflow_05 = pd.read_csv("migration.data/post.processed.census.files/inflow/inflow_05_09_Michigan_processed.csv")
outflow_05 = pd.read_csv("migration.data/post.processed.census.files/outflow/outflow_05_09_Michigan_processed.csv")
inflow_09 = pd.read_csv("migration.data/post.processed.census.files/inflow/inflow_09_13_Michigan_processed.csv")
outflow_09 = pd.read_csv("migration.data/post.processed.census.files/outflow/outflow_09_13_Michigan_processed.csv")
inflow_13 = pd.read_csv("migration.data/post.processed.census.files/inflow/inflow_13_17_Michigan_processed.csv")
outflow_13 = pd.read_csv("migration.data/post.processed.census.files/outflow/outflow_13_17_Michigan_processed.csv")
inflow_16 = pd.read_csv("migration.data/post.processed.census.files/inflow/inflow_16_20_Michigan_processed.csv")
outflow_16 = pd.read_csv("migration.data/post.processed.census.files/outflow/outflow_16_20_Michigan_processed.csv")
